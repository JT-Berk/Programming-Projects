# %%
# rock paper scissors game

# planning phase 

# generate a random list of 3 combinations 

# first must prompt user to make a selection



    print("Welcome to Rock Paper Scissors. Enter -99 to stop playing")


    list1 = ["Rock","Paper","Scissors"]
    
def rps():   
    
    z = random.randint(1,2)
    x = 0

    if (z == 1):
        x = "Rock"
    elif (z == 2):
        x = "Paper"
    elif (z == 3):
        x = "Scissors"

    u = input("Rock, Paper, or Scissors? ")
    
    

    if (u == x):
        print("Tie")
    elif (u == "Rock") & (x == "Paper"):
        print("You lose")
    elif (u == "Rock"):
        if (x == "Scissors"):
            print("You win")
        elif (x == "Paper"):
            print("You Lose")
    elif (u == "Paper"):
        if (x == "Rock"):
            print("You win")
        elif (x == "Scissors"):
            print("You lose")
    elif (u == "Scissors"):
        if (x == "Rock"):
            print("You lose")
        elif (x == "Paper"):
            print("You win")
    

    print("The computer chose:", x)
    
    rps()
    
rps()
# Out:
#   File "<ipython-input-2-c22c1cd84598>", line 11
#     print("Welcome to Rock Paper Scissors. Enter -99 to stop playing")
#     ^
# IndentationError: unexpected indent

# %%
import random
z = random.randint(1,2)
x = 0

if (z == 1):
    x = "Rock"
elif (z == 2):
    x = "Paper"
elif (z == 3):
    x = "Scissors"

u = input("Rock, Paper, or Scissors? ")
    
    

if (u == x):
    print("Tie")
elif (u == "Rock") & (x == "Paper"):
    print("You lose")
elif (u == "Rock"):
    if (x == "Scissors"):
        print("You win")
    elif (x == "Paper"):
        print("You Lose")
elif (u == "Paper"):
    if (x == "Rock"):
        print("You win")
    elif (x == "Scissors"):
        print("You lose")
elif (u == "Scissors"):
    if (x == "Rock"):
        print("You lose")
    elif (x == "Paper"):
        print("You win")
    

print("The computer chose:", x)
# Out:
# Rock, Paper, or Scissors? Scissors
# You lose
# The computer chose: Rock

# %%
def rps():
    import random
    z = random.randint(1,2)
    x = 0

    if (z == 1):
        x = "Rock"
    elif (z == 2):
        x = "Paper"
    elif (z == 3):
        x = "Scissors"

    u = input("Rock, Paper, or Scissors? ")



    if (u == x):
        print("Tie")
    elif (u == "Rock") & (x == "Paper"):
        print("You lose")
    elif (u == "Rock"):
        if (x == "Scissors"):
            print("You win")
        elif (x == "Paper"):
            print("You Lose")
    elif (u == "Paper"):
        if (x == "Rock"):
            print("You win")
        elif (x == "Scissors"):
            print("You lose")
    elif (u == "Scissors"):
        if (x == "Rock"):
            print("You lose")
        elif (x == "Paper"):
            print("You win")


    print("The computer chose:", x)
    
    rps()
rps()
# Out:
# Rock, Paper, or Scissors? Rock
# You lose
# The computer chose: Paper
# Rock, Paper, or Scissors? Rock
# Tie
# The computer chose: Rock
# Rock, Paper, or Scissors? Rock
# Tie
# The computer chose: Rock
# Rock, Paper, or Scissors? Rock
# You lose
# The computer chose: Paper
# Rock, Paper, or Scissors? Rock
# You lose
# The computer chose: Paper
# Rock, Paper, or Scissors? Paper
# Tie
# The computer chose: Paper
# Rock, Paper, or Scissors? Paper
# You win
# The computer chose: Rock
# Rock, Paper, or Scissors? Rock
# Tie
# The computer chose: Rock
# Rock, Paper, or Scissors? Rock
# Tie
# The computer chose: Rock
# Rock, Paper, or Scissors? Rock
# You lose
# The computer chose: Paper
# Rock, Paper, or Scissors? Rock
# Tie
# The computer chose: Rock
